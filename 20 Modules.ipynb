# %% [markdown]
# ##### -- Modules => Built In Modules --
# ##### ---------------------------------
# ##### [1] Module is A File Contain A Set Of Functions
# ##### [2] You Can Import Module in Your App To Help You
# ##### [3] You Can Import Multiple Modules
# ##### [4] You Can Create Your Own Modules
# ##### [5] Modules Saves Your Time

# %%
import random
print(random)
print(f"random float num {random.random()}")
# Out:
# <module 'random' from 'c:\\Program Files\\Python312\\Lib\\random.py'>
# random float num 0.4416686404340804

# %% [markdown]
# ##### show all function inside module

# %%
print(dir(random))
# Out:
# ['BPF', 'LOG4', 'NV_MAGICCONST', 'RECIP_BPF', 'Random', 'SG_MAGICCONST', 'SystemRandom', 'TWOPI', '_ONE', '_Sequence', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_accumulate', '_acos', '_bisect', '_ceil', '_cos', '_e', '_exp', '_fabs', '_floor', '_index', '_inst', '_isfinite', '_lgamma', '_log', '_log2', '_os', '_pi', '_random', '_repeat', '_sha512', '_sin', '_sqrt', '_test', '_test_generator', '_urandom', '_warn', 'betavariate', 'binomialvariate', 'choice', 'choices', 'expovariate', 'gammavariate', 'gauss', 'getrandbits', 'getstate', 'lognormvariate', 'normalvariate', 'paretovariate', 'randbytes', 'randint', 'random', 'randrange', 'sample', 'seed', 'setstate', 'shuffle', 'triangular', 'uniform', 'vonmisesvariate', 'weibullvariate']

# %% [markdown]
# ##### import one or two func from module

# %%
from random import * # =>معناها كل الفنكشنز اللي في random
from random import randint , random

print(f"random float num {random()}")
print(f"random int num {randint (10,100)}")
# Out:
# random float num 0.2208200255288748
# random int num 16

# %%
# Check the Python Version

import sys
print(sys.version)
# Out:
# 3.12.6 (tags/v3.12.6:a4a2d2b, Sep  6 2024, 20:11:23) [MSC v.1940 64 bit (AMD64)]

# %% [markdown]
# ##### -- Modules => Create Your Module --

# %%
import sys
sys.path.append(r"D:\python pr\pyth")

import Module
print(dir(Module))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'sayhello', 'sayhowareyou']

# %%
import Module as m
m.sayhello("ahmed")
m.sayhowareyou("sayed")
# Out:
# hello ahmed
# How Are You sayed

# %%
from Module import sayhowareyou as s
s("ahmed")
# Out:
# How Are You ahmed

# %% [markdown]
# ##### -- Modules => Install External Packages --
# ###### ------------------------------------------
# ###### [1] Module vs Package
# ###### [2] External Packages Downloaded From The Internet
# ###### [3] You Can Install Packages With Python Package Manager PIP
# ###### [4] PIP Install the Package and Its Dependencies
# ###### [5] Modules List "https://docs.python.org/3/py-modindex.html"
# ###### [6] Packages and Modules Directory "https://pypi.org/"
# ###### [7] PIP Manual "https://pip.pypa.io/en/stable/reference/pip_install/"

# %%
import pyfiglet
import termcolor

# print(dir(pyfiglet))
print(pyfiglet.figlet_format("Ahmed Rabie"))
print(termcolor.colored("Ahmed Rabie" , color="red"))

print(termcolor.colored(pyfiglet.figlet_format("Ahmed Rabie") , color="yellow"))
# Out:
#     _    _                        _   ____       _     _
#    / \  | |__  _ __ ___   ___  __| | |  _ \ __ _| |__ (_) ___
#   / _ \ | '_ \| '_ ` _ \ / _ \/ _` | | |_) / _` | '_ \| |/ _ \
#  / ___ \| | | | | | | | |  __/ (_| | |  _ < (_| | |_) | |  __/
# /_/   \_\_| |_|_| |_| |_|\___|\__,_| |_| \_\__,_|_.__/|_|\___|
#
#
# Ahmed Rabie
#     _    _                        _   ____       _     _
#    / \  | |__  _ __ ___   ___  __| | |  _ \ __ _| |__ (_) ___
#   / _ \ | '_ \| '_ ` _ \ / _ \/ _` | | |_) / _` | '_ \| |/ _ \
#  / ___ \| | | | | | | | |  __/ (_| | |  _ < (_| | |_) | |  __/
# /_/   \_\_| |_|_| |_| |_|\___|\__,_| |_| \_\__,_|_.__/|_|\___|
