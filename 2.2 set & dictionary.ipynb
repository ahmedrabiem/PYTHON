# %% [markdown]
# # Set
# ### ---------

# %% [markdown]
# #### [1] set items is not ordered and not indexed and not slicing

# %%
myset ={110,2,"asd",4,5,3}
print(myset)

#print(myset[0]) # ERROR
#print(myset[2:5]) # ERROR
# Out:
# {'asd', 2, 3, 4, 5, 110}

# %%
myset = {110, 2, "asd", 4, 5, 3}
print(myset)

# المحاولة للوصول إلى عنصر باستخدام الفهرسة (والتي غير مدعومة في المجموعات)
try:
    print(myset[0])  # هذا سيتسبب بخطأ
except TypeError:
    pass  # تجاوز الخطأ بدون تنفيذ أي إجراء
# Out:
# {'asd', 2, 3, 4, 5, 110}

# %% [markdown]
# #### [2] set has only immutable data type (number,string,tuple) list and dict are not
# #### immutable => يمكن التعديل عليها

# %%
myset1 ={110,2,"asd",4,5,(1,1,2)}
print(myset1)

myset2 ={110,2,"asd",4,5,[1,1,2]} #ERROR
print(myset2)
# Out:
# {2, 4, 5, 'asd', 110, (1, 1, 2)}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 myset1 ={110,2,"asd",4,5,(1,1,2)}
#       2 print(myset1)
# ----> 4 myset2 ={110,2,"asd",4,5,[1,1,2]} #ERROR
#       5 print(myset2)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# #### [3] items is unique لو عنصر اتكرر بيطبع واحد بس منهم

# %%
myset3 ={110,2,"asd",4,5,"asd"}
print(myset3)
# Out:
# {2, 4, 5, 'asd', 110}

# %% [markdown]
# #### كدا اتعرفنا علي ال set
#
# #### ندخل علي ال set methods
# #### هي نفس قواعد الرياضيات

# %%
### clear()
myset2 ={110,2,"asd",4,5}
myset2 .clear()
print(myset2)
# Out:
# set()

# %% [markdown]
# # Union

# %%
set1 = {3,'ahmed'}
set2 ={110,2,"asd",4,5}
set3 = {"ah", "df"}

print(set1 | set2 | set3)

print(set1.union (set2,set3))
# Out:
# {2, 3, 4, 5, 'asd', 'df', 110, 'ahmed', 'ah'}
# {2, 3, 4, 5, 'asd', 'df', 110, 'ahmed', 'ah'}

# %% [markdown]
# # add بضيف عنصر واحد بس

# %%
set1 = {3,'ahmed'}
set1.add("asdf")
print(set1)
# Out:
# {3, 'asdf', 'ahmed'}

# %% [markdown]
# # copy

# %%
set1 = {3,'ahmed',4}
a= set1.copy()
print(set1)
print(a)
set1.add(234)
print(set1)
print(a)
# Out:
# {3, 4, 'ahmed'}
# {3, 4, 'ahmed'}
# {234, 3, 4, 'ahmed'}
# {3, 4, 'ahmed'}

# %% [markdown]
# #### remove() بتحذف عنصر ولو ادتلها عنصر مش موجود بيطلع ايرور

# %%
g ={234, 3, 4, 'ahmed'}
g.remove(3)
print(g)

g.remove(2)
print(g)
# Out:
# {234, 4, 'ahmed'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 5
#       2 g.remove(3)
#       3 print(g)
# ----> 5 g.remove(2)
#       6 print(g)
#
# KeyError: 2

# %% [markdown]
# #### discard () دي نفس اللي فوق بس مش بتطلع ايرور لو العنصر مش موجود

# %%
g ={234, 3, 4, 'ahmed'}
g.discard(3)
print(g)

g. discard(2)
print(g)
# Out:
# {234, 4, 'ahmed'}
# {234, 4, 'ahmed'}

# %% [markdown]
# # POP () بيطلع عنصر عشوائي

# %%
g ={234, 3, 4, 'ahmed'}
print(g)
# g.pop()
print(g.pop())
print(g)
# Out:
# {234, 3, 'ahmed', 4}
# 234
# {3, 'ahmed', 4}

# %% [markdown]
# # update() كأنك بتعمل اتحاد بالظبط

# %%
set1 = {3,'ahmed',4,5}
set2 ={110,2,"asd",4,5}

set1.update(set2)
print(set1)
# Out:
# {2, 3, 4, 5, 'asd', 110, 'ahmed'}

# %% [markdown]
# #### difference() بطلع الفرق ومش بيأثر علي ال ست بتعتي

# %%
a={1,2,3,4}
b={1,2,3}
print(a.difference(b)) #a-b
print(a)
# Out:
# {4}
# {1, 2, 3, 4}

# %% [markdown]
# #### differance_update بطلع الفرق وبعمل تحديث ل الست بنتاتج

# %%
a={1,2,3,4}
b={1,2}
print(a)
a.difference_update(b)
# print(a.difference_update(b)) #a-b
print(a)
# Out:
# {1, 2, 3, 4}
# {3, 4}

# %% [markdown]
# #### التقاطعintersection

# %%
a={1,2,3,4}
b={1,2}
print(a)
print(a.intersection(b)) #a&b
print(a & b)
print(a)
# Out:
# {1, 2, 3, 4}
# {1, 2}
# {1, 2}
# {1, 2, 3, 4}

# %% [markdown]
# #### intersection_update

# %%
a={1,2,3,4}
b={1,2}
print(a)
print(a.intersection_update(b)) #a&b
print(a)
# Out:
# {1, 2, 3, 4}
# None
# {1, 2}

# %% [markdown]
# #### symmetric_diffrance() المجموعه فرق تقاطعها مع المجموعتين التانيه

# %%
a={1,2,3,5,24,4}
b={1,2,9,3}
print(a)
print(a.symmetric_difference(b)) #a^b
print(a^b)
print(a)
# Out:
# {1, 2, 3, 4, 5, 24}
# {4, 5, 24, 9}
# {4, 5, 24, 9}
# {1, 2, 3, 4, 5, 24}

# %% [markdown]
# #### symmetric_diffrance_update()

# %%
a={1,2,3,5,24,4}
b={1,2,9,3}
#print(a)
print(a.symmetric_difference_update(b)) #a^b
print(a^b)
print(a)
# Out:
# None
# {1, 2, 3, 4, 5, 24}
# {4, 5, 24, 9}

# %% [markdown]
# ### superset() جزئيه وغير جزئيه

# %%
a={1,2,3,5,24,4}
b={1,2,3}
print(a)
print(a.issuperset(b)) #a>=b
print(a>=b)
print(a)
# Out:
# {1, 2, 3, 4, 5, 24}
# True
# True
# {1, 2, 3, 4, 5, 24}

# %% [markdown]
# # issubset

# %%
a={1,2,3,5,24,4}
b={1,2,3,34}
print(a)
print(a.issubset(b)) #a<=b
print(a<=b)
print(a)
# Out:
# {1, 2, 3, 4, 5, 24}
# False
# False
# {1, 2, 3, 4, 5, 24}

# %% [markdown]
# #### isdisjoin بشوف في تقاطع ولا لا

# %%
a={1,2,3,5,24,4}
b={1,2,3}
c={12,10,11}
print(a)
print(a.isdisjoint(b))
print(a.isdisjoint(c)) 

print(a)
# Out:
# {1, 2, 3, 4, 5, 24}
# False
# True
# {1, 2, 3, 4, 5, 24}

# %% [markdown]
# ### ----------------
# ### ---Dictionary--
# ### ----------------

# %% [markdown]
# #### [1] Dict items are contain key : value
# #
# #### [2] Dict key has only immutable data type (number,string,tuple) list and dict are not
# #### immutable => يمكن التعديل عليها

# %%
user ={
    "name" : "ahmed",
    "age" : 20,
    "lan" : "python",
    (1,2,3) : "test",
    1 : "ads"
}
print(user)
# Out:
# {'name': 'ahmed', 'age': 20, 'lan': 'python', (1, 2, 3): 'test', 1: 'ads'}

# %% [markdown]
# ### [3] Dict value can have any data type

# %%
user ={
    "name" : "ahmed",
    "age" : 20,
    "lan" : "python",
    (1,2,3) : "test",
    1 : ["ahmed", "Rabie" ]
}
print(user)
# Out:
# {'name': 'ahmed', 'age': 20, 'lan': 'python', (1, 2, 3): 'test', 1: ['ahmed', 'Rabie']}

# %% [markdown]
# #### [4] Dict key need to be unique

# %%
user ={
    "name" : "ahmed",
    "name" : "sayed",
    "age" : 20,
    "lan" : "python",
    (1,2,3) : "test",
    1 : "ads"
}
print(user)
# Out:
# {'name': 'sayed', 'age': 20, 'lan': 'python', (1, 2, 3): 'test', 1: 'ads'}

# %% [markdown]
# ### [5] Dict is not orderd you access its element with key

# %%
user ={
    "name" : "sayed",
    "age" : 20,
    "lang" : "python",
    (1,2,3) : "test",
    1 : "ads"
}
print(user)

print(user["name"])
print(user.get("name"))

print(user.keys())
print(user.values())
print(user.items())
# Out:
# {'name': 'sayed', 'age': 20, 'lang': 'python', (1, 2, 3): 'test', 1: 'ads'}
# sayed
# sayed
# dict_keys(['name', 'age', 'lang', (1, 2, 3), 1])
# dict_values(['sayed', 20, 'python', 'test', 'ads'])
# dict_items([('name', 'sayed'), ('age', 20), ('lang', 'python'), ((1, 2, 3), 'test'), (1, 'ads')])

# %% [markdown]
# #### TOW-DIMENSIONAL DICT

# %%
user ={
    "name" : "sayed",
    "age" : 20,
    "info": {
        "fcolor":"black",
        "fcar" : "BMW"
    },
    "sayed" : {
        "weight" : 70,
        "length" : 180,
    }
}
print(user)

print(user["info"])
print(user["sayed"])

print(user["info"]["fcolor"])
# Dict len
print(len(user))
print(len(user["info"]))
# Out:
# {'name': 'sayed', 'age': 20, 'info': {'fcolor': 'black', 'fcar': 'BMW'}, 'sayed': {'weight': 70, 'length': 180}}
# {'fcolor': 'black', 'fcar': 'BMW'}
# {'weight': 70, 'length': 180}
# black
# 4
# 2

# %%
info= {
    "fcolor":"black",
    "fcar" : "BMW"
}

sayed = {
    "name" : "sayed",
    "weight" : 70,
    "length" : 180,
    }
learn ={
    "colleg" : "computer scince"
}

person={
    "one" : info,
    "two": sayed,
    'three': learn
}
print(person)
print(person["one"]["fcar"])
# Out:
# {'one': {'fcolor': 'black', 'fcar': 'BMW'}, 'two': {'name': 'sayed', 'weight': 70, 'length': 180}, 'three': {'colleg': 'computer scince'}}
# BMW

# %% [markdown]
# # clear()

# %%
sayed = {
    "name" : "sayed",
    "weight" : 70,
    "length" : 180,
    }
print(sayed)
sayed.clear()
print(sayed)
# Out:
# {'name': 'sayed', 'weight': 70, 'length': 180}
# {}

# %% [markdown]
# # update()

# %%
person1 = {
    "name" : "ahmed"
}
print(person1)
person1["age"] = "20"
print(person1)

person1.update({"country" : "egypt"})
print(person1)
# Out:
# {'name': 'ahmed'}
# {'name': 'ahmed', 'age': '20'}
# {'name': 'ahmed', 'age': '20', 'country': 'egypt'}

# %% [markdown]
# #### copy ()

# %%
person1 = {
    "name" : "ahmed"
}

person2 = person1.copy()
print(person2)
# Out:
# {'name': 'ahmed'}

# %% [markdown]
# #### setdefault() لا دي اسمعلها فيديو ههه

# %%
user = {
    "name" : "Ahmed"
}
print (user)
print (user.setdefault("name", "Rabie"))
print (user)

print("*"*40)

user1 = {
    "name" : "Ahmed"
}
print (user1)
print (user1.setdefault("last name", "Rabie"))
print (user1)

print("*"*40)

user2 = {
    "name" : "Ahmed"
}
print (user2)
print (user2.setdefault("last name"))
print (user2)
# Out:
# {'name': 'Ahmed'}
# Ahmed
# {'name': 'Ahmed'}
# ****************************************
# {'name': 'Ahmed'}
# Rabie
# {'name': 'Ahmed', 'last name': 'Rabie'}
# ****************************************
# {'name': 'Ahmed'}
# None
# {'name': 'Ahmed', 'last name': None}

# %% [markdown]
# #### popitem() برجع اخر عنصر ضفته

# %%
person1 = {
    "name" : "ahmed"
}
person1.update({"country" : "egypt"})
print(person1)
print(person1.popitem())
print(person1)
# Out:
# {'name': 'ahmed', 'country': 'egypt'}
# ('country', 'egypt')
# {'name': 'ahmed'}

# %% [markdown]
# #### items() بحتفظ بالعناصر فيها علي هيئة tuple

# %%
person1 = {
    "name" : "ahmed",
    "country" : "egypt"
}
allitems = person1.items()
print(allitems)
print(person1)
person1["age"] = 20
print(allitems)
# Out:
# dict_items([('name', 'ahmed'), ('country', 'egypt')])
# {'name': 'ahmed', 'country': 'egypt'}
# dict_items([('name', 'ahmed'), ('country', 'egypt'), ('age', 20)])

# %% [markdown]
# #### fromkeys()

# %%
a=("one","two","three")
x=("f")
print(dict.fromkeys(a,x))

print("*"*53)

a=("one","two","three")
x=("f",3)
print(dict.fromkeys(a,x))
# Out:
# {'one': 'f', 'two': 'f', 'three': 'f'}
# *****************************************************
# {'one': ('f', 3), 'two': ('f', 3), 'three': ('f', 3)}
