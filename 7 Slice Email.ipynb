# %% [markdown]
# ### Slice Email

# %%
email = "ahmedrabiehh@gmail.co m"
print (email[0:13])
print (email.rfind("@"))
email.rsplit()
# Out:
# ahmedrabiehh@
# 12
# ['ahmedrabiehh@gmail.co', 'm']

# %%
email = "ahmedrabiehh@"
print (len(email))
print (email.index("@"))
# Out:
# 13
# 12

# %%
email = "ahmedrabiehh@gmail.com"
print (email[:email.index("@")])
# Out:
# ahmedrabiehh

# %%
name = input("please enter your name : ")
email = input("please enter your email : ")
name = name.title().strip()
email = email.strip()
user = email[:email.index("@")]
web = email[email.index("@")+1:]

print(f"your name is : {name} \nand \nyour email is : {email}")
print(f"your Username is : {user} \nand \nyour Website is : {web}")
# Out:
# your name is : Ahmed Rabie
# and
# your email is : ahmedrabie@gmail.com
# your Username is : ahmedrabie
# and
# your Website is : gmail.com
