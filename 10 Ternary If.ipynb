# %% [markdown]
# ### Ternary If

# %% [markdown]
# ##### Condition If true | If condition | Else |Condition If false

# %%
name = input("enter your Fullname: ")
name = name.title().strip()
country = input("enter your country: ").lower()
student = input("Are you a student? \"yes or no\"")
price = 100
cname = "montage"

if country=="egypt" or country== "kuwait":
    print(f"Hello {name} because you are from {country}")
    # if student=="yes":
    #     print(f"the course {cname} price is : ${price- 90}")
    # else:
    #     print(f"the course {cname} price is : ${price-80}")
    print (f"the course {cname} price is : ${price- 90}" if student=="yes" else f"the course {cname} price is : ${price-80}" )
elif country == "ksa":
    print(f"Hello {name} because you are from {country}")
    print(f"the course {cname} price is : ${price- 60}")
else :
    print(f"Hello {name} because you are from {country}")
    print(f"the course {cname} price is : ${price}")
# Out:
# Hello Ahmed Rabie Mohamed because you are from egypt
# the course montage price is : $10

# %%
movierate = 18
age=int(input("How old are you?"))
print("movie is good 4U"if age>movierate else"movie is not good 4U")
# Out:
# movie is not good 4U

# %%
age = int(input("please enter your age"))
print("#"*80)
print("you can write the frist later or full name of the time unit".center(80,"#"))
print("#"*80)
unit = input("please choose time unit :(months, weeks, days) ").strip().lower()

months = age*12
weeks = months *4
day = age*365

if unit=="mothes" or unit=="m":
    print(f"you leve {months:,} months")
elif unit=="weeks" or unit=="w":
    print(f"you leve {weeks:,} weeks")
elif unit=="days" or unit=="d":
    print(f"you leve {day:,} days")
# Out:
# ################################################################################
# ##########you can write the frist later or full name of the time unit###########
# ################################################################################
# you leve 7,300 days
