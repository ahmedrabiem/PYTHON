# %% [markdown]
# ##### --      Exceptions Handling      --
# ##### -- Try | Except | Else | Finally --
# ##### -----------------------------------
# ##### Try     => Test The Code For Errors
# ##### Except  => Handle The Errors
# ##### ----------------------------
# ##### Else    => If No Errors
# ##### Finally => Run The Cod

# %%
try: # Try The Code and Test Errors
    num = int(input("PLS enter num"))
    
except: # Handle The Errors If Its Found
    print("this is not integer")
    
else: # If Theres No Errors
    print(f"good num {num} is intger")
    
finally:
    print ("from finally")
    
print("*"*20)

try:
    num1 = int(input("PLS enter num"))
    
except :
    print("this is not integer")
    
else:
    print(f"good num {num1} is intger")
    
finally:
    print ("from finally")
# Out:
# this is not integer
# from finally
# ********************
# good num 456 is intger
# from finally

# %%
# -----------------------------------
# --      Exceptions Handling      --
# -- Try | Except | Else | Finally --
# --       Advanced Example        --
# -----------------------------------

the_file = None

the_tries = 5

while the_tries > 0:

  try:  # Try To Open The File

    print("Enter The File Name With Absolute Path To Open")

    print(f"You Have {the_tries} Tries Left")

    print("Example: D:\Python\Files\yourfile.extension")

    file_name_and_path = input("File Name => : ").strip()

    the_file = open(file_name_and_path, 'r')

    print(the_file.read())

    break

  except FileNotFoundError:

    print("File Not Found Please Be Sure The Name is Valid")

    the_tries -= 1

  except:

    print("Error Happen")

  finally:

    if the_file is not None:

      the_file.close()

      print("File Closed.")

else:

  print("All Tries Is Done")
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\P'
# <>:19: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\S_AFRICA\AppData\Local\Temp\ipykernel_15780\1751176644.py:19: SyntaxWarning: invalid escape sequence '\P'
#   print("Example: D:\Python\Files\yourfile.extension")
# Enter The File Name With Absolute Path To Open
# You Have 5 Tries Left
# Example: D:\Python\Files\yourfile.extension
# File Not Found Please Be Sure The Name is Valid
# Enter The File Name With Absolute Path To Open
# You Have 4 Tries Left
# Example: D:\Python\Files\yourfile.extension
# File Not Found Please Be Sure The Name is Valid
# Enter The File Name With Absolute Path To Open
# You Have 3 Tries Left
# Example: D:\Python\Files\yourfile.extension
# File Not Found Please Be Sure The Name is Valid
# Enter The File Name With Absolute Path To Open
# You Have 2 Tries Left
# Example: D:\Python\Files\yourfile.extension
# File Not Found Please Be Sure The Name is Valid
# Enter The File Name With Absolute Path To Open
# You Have 1 Tries Left
# Example: D:\Python\Files\yourfile.extension
# File Not Found Please Be Sure The Name is Valid
# All Tries Is Done

# %%
def my(num):
    try:
        print(num/(num-5))
        
    except Exception:
        print("num should not be 5")
        
        
num=int(input("enter num"))
my(num)
# Out:
# num should not be 5
