# %% [markdown]
# ##### -- Practical => Loop on Many Iterators With Zip() --
# ####
# ##### zip() Return A Zip Object Contains All Objects
# ##### zip() Length Is The Length of Lowest Object

# %%
List1= [1,2,3,4,5]
List2= ["a","b","c"]

ziplis= zip(List1 , List2)
print (ziplis)

for i in ziplis:
    print(i , end=" ")
# Out:
# <zip object at 0x0000017170AAA9C0>
# (1, 'a') (2, 'b') (3, 'c')

# %%
tuple1 =("man", "ahmed" , "sayed")
dict1 = {"Name": "Ahmed" , "Age" : 20 , "country": "EGYPT"}

zip1= zip (dict1 , List1)
for n  in zip1:
    print(n)

print("8"*10)

zip1= zip (dict1 , List1)
for n  in zip1:
    print(n)
# Out:
# ('Name', 1)
# ('Age', 2)
# ('country', 3)
# 8888888888
# ('Name', 1)
# ('Age', 2)
# ('country', 3)

# %%
for item1 ,item2 ,item3 ,item4 in zip(List1 , List2 , tuple1 , dict1):
    print("List 1 item =>" , item1)
    print("List 2 item =>" , item2)
    print("Tuple 1 item =>" , item3)
    print("Dict 1 item =>" , item4 , "value =>" , dict1[item4])
# Out:
# List 1 item => 1
# List 2 item => a
# Tuple 1 item => man
# Dict 1 item => Name value => Ahmed
# List 1 item => 2
# List 2 item => b
# Tuple 1 item => ahmed
# Dict 1 item => Age value => 20
# List 1 item => 3
# List 2 item => c
# Tuple 1 item => sayed
# Dict 1 item => country value => EGYPT
