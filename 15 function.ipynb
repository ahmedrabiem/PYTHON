# %% [markdown]
# ### function

# %%
def fristfunc():
    print("hello world")
fristfunc()
a = fristfunc()
print(a)
# Out:
# hello world
# hello world
# None

# %%
def fristfunc():
    return "hello world"
fristfunc()
print(fristfunc()) # دا اللي بيطبع
a = fristfunc()
print(a)
# Out:
# hello world
# hello world

# %% [markdown]
# <small>
#
# #### الفرق بين استخدام `return` وعدم استخدامه في الدوال:
#
# ---
#
# ### بدون استخدام `return`:
# - **الإرجاع**:
#   لا يتم إرجاع أي قيمة (القيمة الافتراضية هي `None`).
#
# - **الاستخدام لاحقًا**:
#   لا يمكن استخدام الناتج أو تخزينه في متغير، لأنه غير موجود.
#
# - **السلوك المتوقع**:
#   تُستخدم الدالة لتنفيذ مهام معينة فقط (مثل الطباعة أو تنفيذ إجراءات) دون الحاجة إلى إرجاع نتائج.
#
# - **متى تُستخدم؟**
#   عندما تريد أن تنفذ الدالة إجراءً دون الحاجة إلى حفظ أو استخدام أي ناتج لاحقًا.
#
# ---
#
# ### مع استخدام `return`:
# - **الإرجاع**:
#   يتم إرجاع قيمة محددة إلى المكان الذي استُدعيت منه الدالة.
#
# - **الاستخدام لاحقًا**:
#   يمكن استخدام الناتج الذي تم إرجاعه أو تخزينه في متغير لاستخدامه لاحقًا.
#
# - **السلوك المتوقع**:
#   تُستخدم للحصول على نتائج من العمليات أو الحسابات التي تنفذها الدالة.
#
# - **متى تُستخدم؟**
#   عندما تحتاج إلى استخدام الناتج من الدالة في مكان آخر أو تخزينه.
#
# </small>

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ###### الفرق بين Function و Procedure و Parameter:
#
# ---
#
# ### <small>Function:</small>
# - **التعريف**:
#   <sub>دالة (Function) تُستخدم لتنفيذ عملية أو حساب معين، وتُرجع دائمًا قيمة أو نتيجة عند استدعائها.</sub>
#
# - **الإرجاع**:
#   <sub>تُرجع قيمة باستخدام `return`.</sub>
#
# - **الاستخدام**:
#   <sub>تُستخدم غالبًا لإجراء حسابات أو عمليات تنتج عنها قيمة تُستخدم لاحقًا.</sub>
#
# - **متى تُستخدم؟**
#   <sub>عندما تحتاج إلى معالجة بيانات أو القيام بعملية حسابية، مع أهمية استخدام الناتج في مكان آخر.</sub>
#
# ---
#
# ### <small>Procedure:</small>
# - **التعريف**:
#   <sub>إجراء (Procedure) يُستخدم لتنفيذ مجموعة من التعليمات، لكنه لا يُرجع قيمة عند استدعائه (إلا إذا كان ذلك غير مباشر).</sub>
#
# - **الإرجاع**:
#   <sub>لا يتم إرجاع أي قيمة (القيمة الافتراضية هي `None`).</sub>
#
# - **الاستخدام**:
#   <sub>تُستخدم لتنفيذ مهام معينة، مثل الطباعة أو تحديث قاعدة بيانات أو إجراء تغييرات.</sub>
#
# - **متى تُستخدم؟**
#   <sub>عندما تحتاج إلى تنفيذ مجموعة من العمليات دون الحاجة إلى نتيجة مباشرة.</sub>
#
# ---
#
# ### <small>Parameter:</small>
# - **التعريف**:
#   <sub>معطى (Parameter) هو قيمة أو متغير يتم تمريره إلى الدالة أو الإجراء لتوفير مدخلات أثناء التنفيذ.</sub>
#
# - **أنواع البراميتر**:
#   <sub>1. **Parameters**: يتم تعريفها في تعريف الدالة أو الإجراء.
#   2. **Arguments**: هي القيم الفعلية التي يتم تمريرها عند استدعاء الدالة.</sub>
#
# - **الاستخدام**:
#   <sub>تُستخدم لتخصيص العمليات داخل الدالة أو الإجراء بناءً على المدخلات.</sub>
#
# - **أمثلة**:
#   <sub>تمرير عددين لدالة جمع لإجراء عملية حسابية بناءً على هذه القيم.</sub>

# %%
def add (n1,n2):
    print(n1+n2)

add(5,7)
# Out:
# 12

# %%
# تعريف الدالة (Parameter هنا هو num1 و num2)
def add_numbers(num1, num2):  
    # result = num1 + num2  # تجمع القيم التي يتم تمريرها
    # return result => لو شلت الكومنت هيشتغل عادي
    return num1+num2
# استدعاء الدالة (Arguments هنا هما 5 و 10)
sum_result = add_numbers(7, 10)
print(f"The sum is: {sum_result}")

print(add_numbers(num1=4, num2=4))
# Out:
# The sum is: 17
# 8

# %%
def add():
    n1=input("PLS ENTER FNUM")
    n2=input("PLS ENTER SNUM")
    while not n1.isdigit() or not n2.isdigit():
        print("PLS ENTER INTEGER NUM :")
        n1=input("PLS ENTER FNUM")
        n2=input("PLS ENTER SNUM")
    else:
        n1=int(n1)
        n2=int(n2)
        print(n1+n2)

add()
# Out:
# 46

# %%
def func(name):
    return(f"hello {name}")
    
name=input("pls enter your name :")
d="Rabie"
print(func(name))
print(func(d))
# Out:
# hello ahmed
# hello Rabie

# %%
def func(name):
    return(f"hello {name}")
    
name=input("pls enter your name :")
d="Rabie"
print(func(name))
print(func(d))
a=0

for n in func(name):
    print (n)
    a+=1
else:
    print("loop is finished")
# Out:
# hello ahmed
# hello Rabie
# h
# e
# l
# l
# o
#
# a
# h
# m
# e
# d
# loop is finished

# %%
def calculate_total(a, b):  # Parameters: a and b
    total = a + b           # Task: Addition
    return total            # Output: Sum of a and b

result = calculate_total(5, 7)  # Calling the function with inputs 5 and 7
print(result)  # Output: 12
# Out:
# 12

# %%
my_L=[1,2,3,4,5]
print(*my_L)
# Out:
# 1 2 3 4 5

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
a=list2+list1
merged_list = [*list1, *list2]
print(merged_list)  # Output: [1, 2, 3, 4, 5, 6]
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6, 1, 2, 3]

# %% [markdown]
# #### Packing and Unpacking argument

# %%
def hello(*peoples): # type => tuple
    for n in peoples:
        print(f"hello {n}")
        
hello("as","ahmed","sayed")
# Out:
# hello as
# hello ahmed
# hello sayed

# %%
def skills(name , *skill): # type => tuple
    print(f"hello {name}")
    for k in skill:
        print(f"your skills is => {k}")
name=input("PLS ENTER YOUR NAME :")
skills(name,"css","js")
# Out:
# hello Ahmed
# your skills is => css
# your skills is => js

# %% [markdown]
# #### Default Parameters

# %%
# def sayh(name="Unknown",age,country): => مش هتشتغل لو اديت قيمه للأولي لازم ادي لكله
# def sayh(name,age="Unknown",country="Unknown"): =>هتشتغل
# def sayh(name,age,country="Unknown"): =>هتشتغل
# def sayh(name="Unknown",age="Unknown",country="Unknown"):=>هتشتغل
def sayh(name="Unknown",age="Unknown",country="Unknown"):
    print(f"hello {name} your age is: {age} and your country is{country}")

sayh("ahmed",20,"EGY")
sayh("sayed",34)
sayh("Mo")
sayh()
# Out:
# hello ahmed your age is: 20 and your country isEGY
# hello sayed your age is: 34 and your country isUnknown
# hello Mo your age is: Unknown and your country isUnknown
# hello Unknown your age is: Unknown and your country isUnknown

# %% [markdown]
# #### Packing and Unpacking KeyWord argument

# %%
user ={
    "fname" : "ahmed",
    "lname" : "sayed",
    "age" : 20,
    "lan": ("python","css"),
    # (1,2,3) : "test", => لو لغيت الكمنت هيطلع ايرور دي بتشتغل علي سترينج بس
    # 1 : "ads"
}
def showskills(**skills): # type => dictionary
    for k,v in skills.items():
        print(f"{k} => {v}")

showskills(html="50%",css="70%")
showskills(**user)
# Out:
# html => 50%
# css => 70%
# fname => ahmed
# lname => sayed
# age => 20
# lan => ('python', 'css')

# %%
t=("html","css","js")
user ={
    "fname" : "ahmed",
    "lname" : "sayed",
    "age" : 20,
    "lan": ("python","css")
}
def showskills(name,*tu,**dic):
    print(f"hello {name} :\nyour lang:")
    for l in tu:
        print(f"=>{l}")
    print("your info :")
    for i,f in dic.items():
        print(f"{i} => {f}")
        
showskills("Ahmed",*t,**user)
print("*"*40)
showskills("sayed","c++","php",fname="sayed",lname="mahmoud")
# Out:
# hello Ahmed :
# your lang:
# =>html
# =>css
# =>js
# your info :
# fname => ahmed
# lname => sayed
# age => 20
# lan => ('python', 'css')
# ****************************************
# hello sayed :
# your lang:
# =>c++
# =>php
# your info :
# fname => sayed
# lname => mahmoud
