# %% [markdown]
# ### Tuple

# %% [markdown]
# #### Tuple شبه الليست في حجات كتير ولكن
# ##### 1- وجود الاقواس مش مهم فيها وبستخدم () Parentheses
# ##### 2- عناصر مرتبه اقدر استخدم index علشان اوصل لعنصر محدد
# ##### 3- Immutable => يعني متقدرش تضيف او تمسح عناصر
# ##### 4- تقدر تحط اي نوع بيانات انت عايزه نفس الليست
# ##### 5- بتستخدم العمليات عليها عادي

# %% [markdown]
# # ####Tuple Method####

# %%
mytuple="ahmed","rabie","sayed"
my=("ahmed","rabie","sayed")
print(type(mytuple))
print(type(my))
print(my)
# Out:
# <class 'tuple'>
# <class 'tuple'>
# ('ahmed', 'rabie', 'sayed')

# %%
a = (1,2,3,4,"sayed","Ahmed")
print(a[-1])
print(a[3])
# Out:
# Ahmed
# 4

# %%
#مش بتقبل اي تعديل
a = (1,2,3,4,"sayed","Ahmed")
a[3]="Ahmed"
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 #مش بتقبل اي تعديل
#       2 a = (1,2,3,4,"sayed","Ahmed")
# ----> 3 a[3]="Ahmed"
#       4 print(a)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### tuple لو عايز اعرف عنصر واحد ك

# %%
#بحط (,) بعد العنصر
a = "Ahmed",
x = ("Ahmed")
print(type(a))
print(type(x))
# Out:
# <class 'tuple'>
# <class 'str'>

# %% [markdown]
# ### بتستخدم العمليات عليها عادي نفس الليست و الاسترينج

# %%
x=(1,2,3,4,"s")
z = 3,4,7
print(x+z)
c= x+ ("ahmed","rabie") +z
print(c)
# Out:
# (1, 2, 3, 4, 's', 3, 4, 7)
# (1, 2, 3, 4, 's', 'ahmed', 'rabie', 3, 4, 7)

# %% [markdown]
# ### Repeat بتمشي علي string ,tuple,list (*)

# %%
mystring="ahmed"
mytuple= ("mohamed","salem")
mylist = [1,2,3]
print(mystring*3)
print(mytuple*3)
print(mylist*3)
# Out:
# ahmedahmedahmed
# ('mohamed', 'salem', 'mohamed', 'salem', 'mohamed', 'salem')
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# ### count

# %%
a= (2,3,4,1,2,3,4,2,2)

print(a.count(2))
# Out:
# 4

# %% [markdown]
# ### index

# %%
x = (1,2,3,4,1,2,3)

#print("the position of the index is: " + x.index(3)) #Error علشان مينفعش اضيف سترينج علي tuple

print("the position of the index is: {:d}".format(x.index(3)) )

print(f"the position of the index is: {x.index(3)}")
# Out:
# the position of the index is: 2
# the position of the index is: 2

# %% [markdown]
# ### Tuple Destruct علشان اخزن العناصر بتعتي في variable

# %%
a = ("A","B","C")
x,y,z = a
print(x)
print(y)
print(z)
# Out:
# A
# B
# C

# %%
#لو عايز اتجاهل عنصر معين
a = ("A","B","C","D")
x,y,_,z=a
print(x)
print(y)
print(z)
# Out:
# A
# B
# D

# %% [markdown]
# # Boolean

# %%
name=" "
print(name.isspace())
# Out:
# True

# %% [markdown]
# # True values

# %%
print(bool("as"))
print(bool(100))
print(bool(True))
print(bool(10.2))
print(bool([1,3,4,4]))
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# # False values

# %%
print(bool(""))
print(bool())
print(bool(0))
print(bool(False))
print(bool([]))
print(bool(None))
# Out:
# False
# False
# False
# False
# False
# False

# %% [markdown]
# # and

# %%
age=20
country = "egypt"
name = "Ahmed"

print (age > 19 and name == "Ahmed" and country =="egypt")

print("*"*10)

age=20
country = "egypt"
name = "Ahmed"

print (age > 30 and name == "Ahmed" and country =="egypt")
# Out:
# True
# **********
# False

# %% [markdown]
# # or

# %%
age=20
country = "egypt"
name = "Ahmed"

print (age > 30 or name == "Ahmed" or country =="KSA")
print("*"*10)

age=20
country = "egypt"
name = "Ahmed"

print (age > 30 or name == "Sayed" or country =="KSA")
# Out:
# True
# **********
# False

# %% [markdown]
# # not

# %%
age=20
print (not age > 30)
print (not age == 20)
# Out:
# True
# False
