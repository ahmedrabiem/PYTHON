# %%
fname = input("what's your first name: ")
lname = input("what's your last name: ")

print(f"Hello {fname} {lname}, how are you?")
# Out:
# Hello        Ahmed    Rabie, how are you?

# %%
fname = input("what's your first name: ")
mname = input("what is yuor middle name")
lname = input("what's your last name: ")
fname = fname.strip().capitalize()
mname = mname.strip().capitalize()
lname = lname.strip().capitalize()
print(f"Hello {fname} {mname:.1s} {lname}, how are you?")
print(f"Hello {fname} {mname.strip().capitalize():.1s} {lname}, how are you?")
# Out:
# Hello Ahmed R Mohamed, how are you?
# Hello Ahmed R Mohamed, how are you?

# %% [markdown]
# ###

# %% [markdown]
# ### لو محددتش نوع المخل اللي انت عايزه هياخد سترينج

# %%
age = input("enter your age :")
print(type(age))
# Out:
# <class 'str'>

# %%
age = int(input("enter your age :"))
print(type(age))
# Out:
# <class 'int'>

# %%
age = int(input("please enter your age : "))
mounths = age*12
days = mounths*30
hours = days*24
print(f"{age} year")
print(f"{mounths:,} mounth")
print(f"{days:,} day")
print(f"{hours:,} hour")
# Out:
# 20 year
# 240 mounth
# 7,200 day
# 172,800 hour
