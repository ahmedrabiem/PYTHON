# %% [markdown]
# ### Membership Operator
#
# ##### in
# ##### not in

# %%
s="Ahmed"
print("A" in s)
print("a" in s)
# Out:
# True
# False

# %%
name = ["ahmed","rabie","mohamed"]
print("ahmed"in name)
print("osama"in name)
print("osama"not in name)
# Out:
# True
# False
# True

# %%
name = input("enter your Fullname: ").title().strip()
countryone = ["Egypt","Kuwait","Bahrain"]
countrytwo = ["Italy","USA","KSA"]
country = input("enter your country: ")

country = country.title().strip()
price = 100
cname = "montage"

if country in countryone:
    print(f"Hello {name} because you are from {country}")
    print(f"the course {cname} price is : ${price- 80}")
elif country in countrytwo:
    print(f"Hello {name} because you are from {country}")
    print(f"the course {cname} price is : ${price- 60}")
else :
    print(f"Hello {name} because you are from {country}")
    print(f"the course {cname} price is : ${price}")
# Out:
# Hello Ahmed because you are from Egypt
# the course montage price is : $20

# %%
admin = ["Ahmed" , "Rabie","Osama","Mohamed"]
name = input("enter your name pls :").strip().capitalize()
# admin.index("Osama")
if name in admin:
    print(f"hello {name} you are admin")
    
    #update
    option=input("Delete or Update your name ").strip().capitalize()
    if option == "Update" or option == "U":
        newname=input("pls enter your name :")
        admin[admin.index(name)] = newname
        print(f"hello {newname} your name updated")
        print (admin)
    
    #delete
    elif option=="Delete" or option == "D":
        admin.remove(name)
        print(admin)
        print("your name removed")
        
    else:
        print("wrong choose")
elif name not in admin:
    new =input(f"hello {name} you are\'n admin ,add you Y,N ").strip().capitalize()
    if new=="Yes" or new =="Y":
        admin.append(name)
        print (admin)
    elif new=="No" or new=="N":
        print("you are\'n added")
# Out:
# hello Ahmed you are admin
# ['Rabie', 'Osama', 'Mohamed']
# your name removed

# %%
adminn=["Ahmed","Rabie","Mohamed"]
name = input("pls enter your name : ").strip().capitalize()


if name in adminn:
    print(f"hello {name} you are admin")
    option=input("Update or Remove?").strip().capitalize()
    if option!="Update" and option != "U" and option !="R" and option !="Remove":
        print ("pls enter right option :")
        option=input("Update or Remove?").strip().capitalize()
    if option =="Update" or option =="U":
        updaten=input("pls enter new name :").capitalize().strip()
        adminn[adminn.index(name)] = updaten
        print("your name is updated")
        print(adminn)
    elif option=="Delete" or option == "D":
        adminn.remove(name)
        print(adminn)
        print("your name removed")
elif name not in adminn:
        print("you are\'n admin")
        new=input("add or end pross :").strip().capitalize()
        if new!="Add" and new != "A" and new !="E" and option !="End":
                print("pls enter right word")
                new=input("add or end pross :").strip().capitalize()
        if new=="Add" or "A":
                print(f"hello {name} you are admin")
                adminn.append(name)
                print(adminn)
        elif new =="E" and option =="End":
                print("pross is end")
# Out:
# you are'n admin
# hello Omar you are admin
# ['Ahmed', 'Rabie', 'Mohamed', 'Omar']

# %%
adminn=["Ahmed","Rabie","Mohamed"]
name = input("pls enter your name : ").strip().capitalize()


if name in adminn:
    print(f"hello {name} you are admin")
    option= input("pls choose Update or Remove :").strip().capitalize()
    if option == "Update" or option == "U":
        print("you choose Update")
        upd = input("pls enter new name :").strip().capitalize()
        adminn[adminn.index(name)] = upd
        print("your name is updated")
        print(adminn)
        
    elif option == "Remove" or option == "R":
        print("you choose Remove")
        adminn.remove(name)
        print(adminn)
        print("your name removed")
        
if name not in adminn:
    option2 = input("you ar not admin , add or end :").strip().capitalize()
    if option2=="Add" or option2 == "A":
        print("you choose Add")
        adminn.append(name)
        print(adminn)
            
    else:
        print("you choose End")
# Out:
# you choose Add
# ['Ahmed', 'Rabie', 'Mohamed', 'Atef']
