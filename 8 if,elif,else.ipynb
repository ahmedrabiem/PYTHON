# %% [markdown]
# ### IF & ELIF &ELSE

# %%
name = input("enter your Fullname: ").title().strip()
# name = name
country = input("enter your country: ").capitalize()
price = 100
cname = "montage"

if country=="Egypt" or country== "Kuwait":
    print(f"Hello {name} because you are from {country}")
    print(f"the course {cname} price is : ${price- 80}")
elif country == "KSA":
    print(f"Hello {name} because you are from {country}")
    print(f"the course {cname} price is : ${price- 60}")
else :
    print(f"Hello {name} because you are from {country}")
    print(f"the course {cname} price is : ${price}")
# Out:
# Hello Ahmed Rabie because you are from Egypt
# the course montage price is : $20

# %%
m = int(input("Pls enter your grade : "))
if m>100 or m<0:
    print("Pls enter right grade :")
    m = int(input("Pls enter your grade : "))
    if m<=100 and m>=85:
        print("A")
    elif m< 85 and m>=70:
        print("B")
    elif m< 70 and m>=50:
        print("c")
    else:
        print("F")
# Out:
# Pls enter right grade :
# c
