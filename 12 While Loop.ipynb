# %% [markdown]
# ##### while condition is true
# ##### code will run

# %%
a=1
while a < 8:
    print (a)
    a+=1
else:
    print("Loop Is Done")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# Loop Is Done

# %%
myf=["ah","ma","sa","da","js","py","ht"]
a=0
while a<len(myf):
    print(myf[a])
    a+=1
else:
    print("Loop Is Done")
# Out:
# ah
# ma
# sa
# da
# js
# py
# ht
# Loop Is Done

# %%
myf=["ah","ma","sa","da","js","py","ht","as","df","df"]
a=0
while a<len(myf):
    print(f"#{str(a+1).zfill(2)} {myf[a]}")
    a+=1
# Out:
# #01 ah
# #02 ma
# #03 sa
# #04 da
# #05 js
# #06 py
# #07 ht
# #08 as
# #09 df
# #10 df

# %%
while False: # مش هيطبع حاجه
    print("Ahmed")

# %% [markdown]
# #### تطبيق فكره

# %%
myfweb=[]
max = 5
print("you can add 5 web: ")

while max >0 :
    x = input("do you want to continue?yes or no")
    if x == "yes":
        web=input("enter web without https://")
        myfweb.append(f"https:// {web.strip().lower()}")
        max -=1
        print(f"website added,{max} places left")
        print (f"your F Web :{myfweb}")
    if x == "no":
        print("end")
        break
else:
    print("you can't add more")

# %%
myfweb=[]
max = 5
print("you can add 5 web: ")

while max >0 :
    x = input("do you want to continue?yes or no")
    if x == "yes":
        web=input("enter web without https://")
        myfweb.append(f"https:// {web.strip().lower()}")
        max -=1
        print(f"website added,{max} places left")
        print (f"your F Web :{myfweb}")
    if x == "no":
        print("end")
        break
else:
    print("you can't add more")
# Out:
# you can add 5 web:
# website added,4 places left
# your F Web :['https:// sad']
# end

# %% [markdown]
# ### 2

# %%
myfcar=[]
max = 5
while max>0:
    car= input("Enter your favorite car type : ")
    myfcar.append(car.upper().strip())
    max -=1
    print(f"you have {max} places")
    # myfcar.sort()
    print(f"list of your f car{myfcar}")
else:
    print("you can\'t add more")

myfcar.sort()
index =0

if len(myfcar)>0:
    print("List of your F Car")
    while index < len(myfcar):
       print(f"#{str(index+1).zfill(2)}",myfcar[index])
       index +=1
    else:
       print("END")
# Out:
# you have 4 places
# list of your f car['SAD']
# you have 3 places
# list of your f car['SAD', 'F']
# you have 2 places
# list of your f car['SAD', 'F', 'M']
# you have 1 places
# list of your f car['SAD', 'F', 'M', 'P']
# you have 0 places
# list of your f car['SAD', 'F', 'M', 'P', 'VB']
# you can't add more
# List of your F Car
# #01 F
# #02 M
# #03 P
# #04 SAD
# #05 VB
# END

# %%
mylist = []
a = 6

while a > 0:
    admin = input("Enter admin name: ").strip().title()  # لتحسين تنسيق الأسماء
    mylist.append(admin)  # إضافة الاسم إلى القائمة
    print(f"You have {a - 1} places left")  # التصحيح هنا ليظهر العدد المتبقي بعد إدخال الاسم
    print(f"Admin name added: {admin}")
    a -= 1
else:
    print("Your list is full.")

# ترتيب القائمة أبجدياً
mylist.sort()

# عرض قائمة الإداريين
index = 0
if len(mylist) > 0:
    print("\nList of admins:")
    while index < len(mylist):
        print(f"#{str(index + 1).zfill(2)} {mylist[index]}")  # الترقيم المنسق
        index += 1
# Out:
# You have 5 places left
# Admin name added: Ahmed
# You have 4 places left
# Admin name added: Sayed
# You have 3 places left
# Admin name added: Rabie
# You have 2 places left
# Admin name added: Maher
# You have 1 places left
# Admin name added: Naser
# You have 0 places left
# Admin name added: Mohamed
# Your list is full.
#
# List of admins:
# #01 Ahmed
# #02 Maher
# #03 Mohamed
# #04 Naser
# #05 Rabie
# #06 Sayed

# %% [markdown]
# ### 3- Password Guess

# %%
tries = 5
truepas="ahmed&"
inputpas = input("enter passwored : ")

while inputpas != truepas :
    tries-=1
    print(f"wrong pas ,{"last" if tries==0 else tries} chance")
    inputpas = input("enter passwored : ")

    if tries == 0:
        print("All tries are finished.")
        break
else:
    print("correct pas")
# Out:
# wrong pas ,4 chance
# wrong pas ,3 chance
# wrong pas ,2 chance
# wrong pas ,1 chance
# wrong pas ,last chance
# All tries are finished.

# %%
tries = 3  # عدد المحاولات المتاحة

while tries >= 0:
    password = input("Enter your password: ")
    if password == "ahmed&":
        print("Access granted!")
        break
    else:
        tries -= 1
        print(f"Incorrect password. {"last"if tries==0 else tries} tries left.")
        
    if tries == 0:
        print("All tries are finished.")
        break
# Out:
# Incorrect password. 2 tries left.
# Incorrect password. 1 tries left.
# Incorrect password. last tries left.
# All tries are finished.

# %%
m=int(input("How many languages ​​do you speak?"))
x = m
list1=[]
while m>0:
    lang=input(f"Pls enter lang{m}: ").capitalize().strip()
    list1.append(lang)
    list1.sort()
    m-=1
else:
    print(f"List of your {x} lang : {list1}")
    ("loop is finished")
# Out:
# List of your 5 lang : ['A', 'B', 'E', 'F', 'S']
